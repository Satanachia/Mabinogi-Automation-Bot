# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np 
from PIL import ImageGrab
import cv2
import pyautogui
import time
import datetime

import pytesseract
pytesseract.pytesseract.tesseract_cmd = 'C:/Program Files/Tesseract-OCR/tesseract'

import random

ir_factor = 1

def grab_screen():
    screen = np.array(ImageGrab.grab())
    screen = cv2.cvtColor(screen, cv2.COLOR_BGR2GRAY)
    screen = cv2.resize(screen,None,fx=1/ir_factor,fy=1/ir_factor)
    return screen

def load_image(img_name):
    img = cv2.imread(img_name)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.resize(img,None,fx=1/ir_factor,fy=1/ir_factor)
    return img

def click(img, x, y):
    img[x-10:x+10, y-10:y+10] = 0
    return img

def logout(img):
    click(img, 980, 670)
    for i in range(7):
        click(img, 410+28*i, 1600)
    click(img, 600, 1900)
    click(img, 660, 1880)
    click(img, 590, 910)
    click(img, 610, 960)
    click(img, 690, 1020)
    
    click(img, 610, 1000)
    click(img, 680, 1150)
    
    click(img, 640, 290)
    return img

def image_confirm(img2):
    screen = img2[0:600, 0:900]
    confirm = "./confirms/dai_confirm.png"
    img = load_image(confirm)
    res = cv2.matchTemplate(screen, img, cv2.TM_SQDIFF_NORMED)
    min_val, _, min_loc, _ = cv2.minMaxLoc(res)
    click(img2, min_loc[1]+20, min_loc[0]+20)
    return img2

# %%
screen = load_image("./menu6.png")
print(screen.shape)
screen = image_confirm(screen)
fig=plt.figure(figsize=(1920/120, 1080/120))
plt.imshow(screen)
plt.show()



# text_cutout = screen[775:820, 450:775]
# text_cutout = cv2.resize(text_cutout,None,fx=4,fy=4)
# ret, text_cutout = cv2.threshold(text_cutout,127,255,cv2.THRESH_BINARY)
# text = pytesseract.image_to_string(text_cutout, config='--psm 12 --oem 3')
# print(text)
# fig=plt.figure(figsize=(1920/120, 1080/120))
# plt.imshow(text_cutout)
# plt.show()

# text_cutout = screen[1010:1060, 450:900]
# text_cutout = cv2.resize(text_cutout,None,fx=4,fy=4)
# ret, text_cutout = cv2.threshold(text_cutout,127,255,cv2.THRESH_BINARY)
# text = pytesseract.image_to_string(text_cutout, config='--psm 12 --oem 3')
# print(text)
# fig=plt.figure(figsize=(1920/120, 1080/120))
# plt.imshow(text_cutout)
# plt.show()
# Out:
# (1140, 1920)

# %% [markdown]
# # Initialize Squires

# %%
from importlib import reload
import squirebot
reload(squirebot)
from squirebot import SquireBot
import time

sb = SquireBot(dimx=1140, dimy=1920, apply_factor=True)
# Out:
# Initialized

# %% [markdown]
# # Complete and Reassign Missions

# %%
# Main Account - Money
missions_by_id = {0: [2, 5, 8], 1: [5, 2, 8], 2: [2, 5, 8], 3: [2, 5, 8],
                      4: [5, 2, 8], 5: [5, 2, 8], 6: [5, 2, 8], 7: [5, 2, 8],
                      8: [2, 5, 8], 9: [5, 2, 8], 10: [2, 5, 8], 11: [2, 5, 8]}
action = sb._reassign_missions
sb.execute_action_on_squires(8, 12, action, missions_by_id=missions_by_id)

# %%
# Main Account - Points
missions_by_id = {0: [1, 4, 7], 1: [1, 4, 7], 2: [1, 4, 7], 3: [1, 4, 7],
                      4: [1, 4, 7], 5: [1, 4, 7], 6: [1, 4, 7], 7: [1, 4, 7],
                      8: [1, 4, 7], 9: [1, 4, 7], 10: [1, 4, 7], 11: [1, 4, 7]}
action = sb._reassign_missions
sb.execute_action_on_squires(6, 11, action, missions_by_id=missions_by_id)

# %%
# Side Account - Money
missions_by_id = {0: [2, 4, 5], 1: [2, 4, 5], 2: [2, 4, 5], 3: [2, 4, 5],
                      4: [2, 4, 5], 5: [2, 4, 5], 6: [2, 4, 5], 7: [2, 4, 5],
                      8: [2, 4, 5], 9: [2, 4, 5], 10: [2, 4, 5]}
action = sb._reassign_missions
sb.execute_action_on_squires(6, 8, action, missions_by_id=missions_by_id)

# %%
# Side Account - Points
missions_by_id = {0: [-1, 1, 3], 1: [-1, 1, 3], 2: [-1, 1, 3], 3: [-1, 1, 3],
                      4: [-1, 1, 3], 5: [-1, 1, 3], 6: [-1, 1, 3], 7: [-1, 1, 3],
                      8: [-1, 1, 3], 9: [-1, 1, 3], 10: [-1, 1, 3]}
action = sb._reassign_missions
sb.execute_action_on_squires(0, 11, action, missions_by_id=missions_by_id)

# %%
# Side Account - Points (Dai Training)
missions_by_id = {0: [1, 3, -1], 1: [1, 3, -1], 2: [1, 3, -1], 3: [1, 3, -1],
                      4: [1, 3, -1], 5: [1, 3, -1], 6: [1, 3, -1], 7: [1, 3, -1],
                      8: [1, 3, -1], 9: [1, 3, -1], 10: [1, 3, -1]}
action = sb._reassign_missions
sb.execute_action_on_squires(0, 11, action, missions_by_id=missions_by_id)

# %%
# Side Account - Points
missions_by_id = {0: {'kanna':-1, 'logan':3, 'dai':0}, 1: {'kanna':-1, 'logan':3, 'dai':0}, 
                  2: {'kanna':-1, 'logan':3, 'dai':0}, 3: {'kanna':-1, 'logan':3, 'dai':0},
                  4: {'kanna':-1, 'logan':3, 'dai':0}, 5: {'kanna':-1, 'logan':3, 'dai':0}, 
                  6: {'kanna':-1, 'logan':3, 'dai':0}, 7: {'kanna':-1, 'logan':3, 'dai':0},
                  8: {'kanna':-1, 'logan':3, 'dai':0}, 9: {'kanna':-1, 'logan':3, 'dai':0}, 
                  10: {'kanna':-1, 'logan':3, 'dai':0}}
action = sb._reassign_missions
sb.execute_action_on_squires(0, 1, action, missions_by_id=missions_by_id)
# Out:
# Finished

# %% [markdown]
# # Advanced Squire Training

# %%
missions_by_id = {0: [0, 3, -1], 1: [0, -1, 6], 2: [0, -1, 6], 3: [0, -1, 6],
                      4: [0, -1, 6], 5: [0, -1, 6], 6: [0, -1, 6], 7: [0, -1, 6],
                      8: [0, -1, 6], 9: [0, -1, 6], 10: [0, -1, 6], 11: [0, -1, 6]}
action = sb._train_advanced_squire
sb.execute_action_on_squires(0, 11, action, missions_by_id=missions_by_id, mission_number=3)

# %%
missions_by_id = {0: [3, 0, -1], 1: [0, 6, -1], 2: [0, 6, -1], 3: [0, 6, -1],
                      4: [0, 6, -1], 5: [0, 6, -1], 6: [0, 6, -1], 7: [0, 6, -1],
                      8: [0, 6, -1], 9: [0, 6, -1], 10: [0, 6, -1], 11: [0, 6, -1]}
start_time = time.time()
print("Starting Adv Training")
action = sb._train_advanced_squire
sb.execute_action_on_squires(5, 11, action, missions_by_id=missions_by_id)
#start_time = float('-Inf')
while True:
    print("Finished 1 Cycle")
    while time.time() - start_time < 2200:
        time.sleep(30)
    action = sb._train_advanced_squire
    sb.execute_action_on_squires(0, 11, action, missions_by_id=missions_by_id)
    start_time = time.time()

# %%
# Alt
missions_by_id = {0: [0, -1, 3], 1: [0, -1, 3], 2: [0, -1, 3], 3: [0, 3, -1],
                      4: [0, -1, 3], 5: [0, -1, 3], 6: [0, -1, 3], 7: [0, -1, 3],
                      8: [0, -1, 3], 9: [0, -1, 3], 10: [0, -1, 3], 11: [0, -1, 3]}
action = sb._train_advanced_squire
sb.execute_action_on_squires(10, 11, action, missions_by_id=missions_by_id, mission_number=3)

# %%
missions_by_id = {0: {'kanna':-1, 'logan':3, 'dai':0}, 1: {'kanna':-1, 'logan':3, 'dai':0}, 
                  2: {'kanna':-1, 'logan':3, 'dai':0}, 3: {'kanna':-1, 'logan':3, 'dai':0},
                  4: {'kanna':-1, 'logan':3, 'dai':0}, 5: {'kanna':-1, 'logan':3, 'dai':0}, 
                  6: {'kanna':-1, 'logan':3, 'dai':0}, 7: {'kanna':-1, 'logan':3, 'dai':0},
                  8: {'kanna':-1, 'logan':3, 'dai':0}, 9: {'kanna':-1, 'logan':3, 'dai':0}, 
                  10: {'kanna':-1, 'logan':3, 'dai':0}}
training_ids = {0: [8], 1: [8], 2: [8], 3: [8],
                4: [3], 5: [8], 6: [8], 7: [8],
                8: [8], 9: [8], 10: [8]}

print("Starting Adv Training")
start_time = time.time()
action = sb._train_advanced_squire
sb.execute_action_on_squires(0, 11, action, missions_by_id=missions_by_id, training_by_id=training_ids)
# start_time = float('-Inf')
while True:
    print("Finished 1 Cycle")
    while time.time() - start_time < 2260:
        print(time.time()-start_time)
        time.sleep(60)
    
    start_time = time.time()
    action = sb._train_advanced_squire
    sb.execute_action_on_squires(0, 11, action, missions_by_id=missions_by_id, training_by_id=training_ids)
# Out:
# Starting Adv Training
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# <ipython-input-8-ef7fec59a34c> in <module>
#      12 start_time = time.time()
#      13 action = sb._train_advanced_squire
# ---> 14 sb.execute_action_on_squires(5, 11, action, missions_by_id=missions_by_id, training_by_id=training_ids)
#      15 # start_time = float('-Inf')
#      16 while True:
#
# ~\Documents\GitHub\ProjectPhoenix\squirebot.py in execute_action_on_squires(self, start, num_chars, action, **kwargs)
#      33             kwargs['squire_id'] = i
#      34             self._login(i)
# ---> 35             action(**kwargs)
#      36             self._logout()
#      37
#
# ~\Documents\GitHub\ProjectPhoenix\squirebot.py in _train_advanced_squire(self, missions_by_id, squire_id, training_by_id, mission_number, **kwargs)
#      54         self._move_to_squire("kanna", squire_id)
#      55         self._end_training()
# ---> 56         self._converse_with_squire()
#      57
#      58         training = training_by_id[squire_id][0]
#
# ~\Documents\GitHub\ProjectPhoenix\squirebot.py in _converse_with_squire(self)
#      80         self._talk_to_squire(talk_delay=2)
#      81         for i in range(3):
# ---> 82             self._click_through_text()
#      83             time.sleep(1)
#      84             self._answer_conv_question()
#
# ~\Documents\GitHub\ProjectPhoenix\squirebot.py in _click_through_text(self)
#     102         while not self._element_exists(conv_confirm, 0.08) and \
#     103                 time.time()-start_time < 20:
# --> 104             self._mabi_click(980, 530, delay=0.5, apply_sfactor=self.apply_factor)
#     105
#     106     def _answer_conv_question(self):
#
# ~\Documents\GitHub\ProjectPhoenix\squirebot.py in _mabi_click(self, h, w, delay, clickDelay, multi_click, apply_sfactor, apply_cfactor)
#     292
#     293         for i in range(multi_click):
# --> 294             pyautogui.moveTo(w+y_sfactor+y_cfactor, h+x_sfactor+x_cfactor)
#     295             pyautogui.mouseDown();
#     296             time.sleep(clickDelay);
#
# C:\ProgramData\Anaconda3\envs\squire\lib\site-packages\pyautogui\__init__.py in moveTo(x, y, duration, tween, pause, logScreenshot, _pause)
#     809       None
#     810     """
# --> 811     _failSafeCheck()
#     812     x, y = _unpackXY(x, y)
#     813
#
# C:\ProgramData\Anaconda3\envs\squire\lib\site-packages\pyautogui\__init__.py in _failSafeCheck()
#    1239 def _failSafeCheck():
#    1240     if FAILSAFE and tuple(position()) in FAILSAFE_POINTS:
# -> 1241         raise FailSafeException('PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.')
#    1242
#    1243
#
# FailSafeException: PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.

# %%
a

# %% [markdown]
# # Macros

# %%
# Buy boxes
int_seals = 653
sb.box_buying(int_seals)
# Out:
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# <ipython-input-44-074c8eb14e94> in <module>
#       1 # Buy boxes
#       2 int_seals = 653
# ----> 3 sb.box_buying(int_seals)
#
# ~\Documents\GitHub\ProjectPhoenix\squirebot.py in box_buying(self, int_seals)
#     312         self.alt_tab()
#     313         for i in range(int_seals//30):
# --> 314             self._mabi_click(90, 1645, delay=0.1)
#     315             self._mabi_click(280, 1645, delay=0.9)
#     316             self._mabi_click(395, 1795, delay=0.9)
#
# ~\Documents\GitHub\ProjectPhoenix\squirebot.py in _mabi_click(self, h, w, delay, clickDelay, multi_click, apply_sfactor, apply_cfactor)
#     290
#     291         for i in range(multi_click):
# --> 292             pyautogui.moveTo(w+y_sfactor+y_cfactor, h+x_sfactor+x_cfactor)
#     293             pyautogui.mouseDown();
#     294             time.sleep(clickDelay);
#
# C:\ProgramData\Anaconda3\envs\squire\lib\site-packages\pyautogui\__init__.py in moveTo(x, y, duration, tween, pause, logScreenshot, _pause)
#     809       None
#     810     """
# --> 811     _failSafeCheck()
#     812     x, y = _unpackXY(x, y)
#     813
#
# C:\ProgramData\Anaconda3\envs\squire\lib\site-packages\pyautogui\__init__.py in _failSafeCheck()
#    1239 def _failSafeCheck():
#    1240     if FAILSAFE and tuple(position()) in FAILSAFE_POINTS:
# -> 1241         raise FailSafeException('PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.')
#    1242
#    1243
#
# FailSafeException: PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.

# %%
num_syn = 40
sb.synthesize(num_syn)

# %% [markdown]
# # Test Functions

# %%
sb.alt_tab()
for i in range(50):
    pyautogui.mouseDown(); 
    time.sleep(0.1); 
    pyautogui.mouseUp()

# %%
import time
missions_by_id = {0: [3, 0, -1], 1: [0, -1, 6], 2: [0, -1, 6], 3: [0, -1, 6],
                      4: [0, -1, 6], 5: [0, -1, 6], 6: [0, -1, 6], 7: [0, -1, 6],
                      8: [0, -1, 6], 9: [0, -1, 6], 10: [0, -1, 6], 11: [0, -1, 6]}

sb.alt_tab()
# sb._reassign_missions(missions_by_id, 0)
# sb._reset_char_screen()
# sb._converse_with_squire()
# sb._start_training(3)
time.sleep(2200)
while True:
    sb._reassign_missions(missions_by_id, 0)
    sb._reset_char_screen()
    sb._end_training()
    sb._converse_with_squire()
    sb._start_training(3)
    time.sleep(2200)

# %%
sb.alt_tab()
for i in range(3):
    sb._click_through_text()
    sb._answer_conv_question()
    sb._end_conv()

# %%
sb.alt_tab()
sb._end_conv()

# %%
import pyautogui
from directkeys import PressKey, ReleaseKey, W, A, S, D, SHIFT, CTRL, ESC, C
import time
sb.alt_tab()

#sb._end_training()
sb._converse_with_squire()
sb._start_training(1)

# %%
def do_nothing(squire_id):
    return

action = do_nothing
sb.execute_action_on_squires(10, 11, action)

# %% [markdown]
# ####

# %%
num_leathers = 85
sb.make_leather_straps(num_leathers)

# %%
sb.alt_tab()
sb._select_squire('kanna')
