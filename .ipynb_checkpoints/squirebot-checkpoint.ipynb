# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np 
from PIL import ImageGrab
import cv2
import pyautogui
import time
import datetime

import pytesseract
pytesseract.pytesseract.tesseract_cmd = 'C:/Program Files/Tesseract-OCR/tesseract'

import random

ir_factor = 1

def grab_screen():
    screen = np.array(ImageGrab.grab())
    screen = cv2.cvtColor(screen, cv2.COLOR_BGR2GRAY)
    screen = cv2.resize(screen,None,fx=1/ir_factor,fy=1/ir_factor)
    return screen

def load_image(img_name):
    img = cv2.imread(img_name)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.resize(img,None,fx=1/ir_factor,fy=1/ir_factor)
    return img

def click(img, x, y):
    img[x-10:x+10, y-10:y+10] = 0
    return img

def logout(img):
    click(img, 980, 670)
    for i in range(7):
        click(img, 410+28*i, 1600)
    click(img, 600, 1900)
    click(img, 660, 1880)
    click(img, 590, 910)
    click(img, 610, 960)
    click(img, 690, 1020)
    
    click(img, 610, 1000)
    click(img, 680, 1150)
    
    click(img, 640, 290)
    return img

# %%
screen = load_image("./text1.png")
print(screen.shape)
screen = logout(screen)
fig=plt.figure(figsize=(1920/120, 1080/120))
plt.imshow(screen)
plt.show()


# text_cutout = screen[775:820, 450:775]
# text_cutout = cv2.resize(text_cutout,None,fx=4,fy=4)
# ret, text_cutout = cv2.threshold(text_cutout,127,255,cv2.THRESH_BINARY)
# text = pytesseract.image_to_string(text_cutout, config='--psm 12 --oem 3')
# print(text)
# fig=plt.figure(figsize=(1920/120, 1080/120))
# plt.imshow(text_cutout)
# plt.show()

text_cutout = screen[1010:1060, 450:900]
text_cutout = cv2.resize(text_cutout,None,fx=4,fy=4)
ret, text_cutout = cv2.threshold(text_cutout,127,255,cv2.THRESH_BINARY)
text = pytesseract.image_to_string(text_cutout, config='--psm 12 --oem 3')
print(text)
fig=plt.figure(figsize=(1920/120, 1080/120))
plt.imshow(text_cutout)
plt.show()
# Out:
# (1140, 1920)
# Start a Conversation
#
# Counsel
#
# Go Out
#
# Manage Training

# %% [markdown]
# # Initialize Squires

# %%
from importlib import reload
import squirebot
reload(squirebot)
from squirebot import SquireBot
import time

sb = SquireBot(dimx=1140, dimy=1920, apply_factor=True)
# Out:
# Initialized

# %% [markdown]
# # Complete and Reassign Missions

# %%
# Main Account - Money
missions_by_id = {0: [2, 5, 8], 1: [5, 2, 8], 2: [2, 5, 8], 3: [2, 5, 8],
                      4: [5, 2, 8], 5: [5, 2, 8], 6: [5, 2, 8], 7: [5, 2, 8],
                      8: [2, 5, 8], 9: [5, 2, 8], 10: [2, 5, 8], 11: [2, 5, 8]}
action = sb._reassign_missions
sb.execute_action_on_squires(8, 12, action, missions_by_id=missions_by_id)

# %%
# Main Account - Points
missions_by_id = {0: [1, 4, 7], 1: [1, 4, 7], 2: [1, 4, 7], 3: [1, 4, 7],
                      4: [1, 4, 7], 5: [1, 4, 7], 6: [1, 4, 7], 7: [1, 4, 7],
                      8: [1, 4, 7], 9: [1, 4, 7], 10: [1, 4, 7], 11: [1, 4, 7]}
action = sb._reassign_missions
sb.execute_action_on_squires(6, 11, action, missions_by_id=missions_by_id)

# %%
# Side Account - Money
missions_by_id = {0: [2, 4, 5], 1: [2, 4, 5], 2: [2, 4, 5], 3: [2, 4, 5],
                      4: [2, 4, 5], 5: [2, 4, 5], 6: [2, 4, 5], 7: [2, 4, 5],
                      8: [2, 4, 5], 9: [2, 4, 5], 10: [2, 4, 5]}
action = sb._reassign_missions
sb.execute_action_on_squires(6, 8, action, missions_by_id=missions_by_id)

# %%
# Side Account - Points
missions_by_id = {0: [-1, 1, 3], 1: [-1, 1, 3], 2: [-1, 1, 3], 3: [-1, 1, 3],
                      4: [-1, 1, 3], 5: [-1, 1, 3], 6: [-1, 1, 3], 7: [-1, 1, 3],
                      8: [-1, 1, 3], 9: [-1, 1, 3], 10: [-1, 1, 3]}
action = sb._reassign_missions
sb.execute_action_on_squires(0, 11, action, missions_by_id=missions_by_id)

# %%
# Side Account - Points (Dai Training)
missions_by_id = {0: [1, 3, -1], 1: [1, 3, -1], 2: [1, 3, -1], 3: [1, 3, -1],
                      4: [1, 3, -1], 5: [1, 3, -1], 6: [1, 3, -1], 7: [1, 3, -1],
                      8: [1, 3, -1], 9: [1, 3, -1], 10: [1, 3, -1]}
action = sb._reassign_missions
sb.execute_action_on_squires(0, 11, action, missions_by_id=missions_by_id)

# %% [markdown]
# # Advanced Squire Training

# %%
missions_by_id = {0: [0, 3, -1], 1: [0, -1, 6], 2: [0, -1, 6], 3: [0, -1, 6],
                      4: [0, -1, 6], 5: [0, -1, 6], 6: [0, -1, 6], 7: [0, -1, 6],
                      8: [0, -1, 6], 9: [0, -1, 6], 10: [0, -1, 6], 11: [0, -1, 6]}
action = sb._train_advanced_squire
sb.execute_action_on_squires(0, 11, action, missions_by_id=missions_by_id, mission_number=3)

# %%
missions_by_id = {0: [3, 0, -1], 1: [0, 6, -1], 2: [0, 6, -1], 3: [0, 6, -1],
                      4: [0, 6, -1], 5: [0, 6, -1], 6: [0, 6, -1], 7: [0, 6, -1],
                      8: [0, 6, -1], 9: [0, 6, -1], 10: [0, 6, -1], 11: [0, 6, -1]}
start_time = time.time()
print("Starting Adv Training")
action = sb._train_advanced_squire
sb.execute_action_on_squires(9, 11, action, missions_by_id=missions_by_id)
#start_time = float('-Inf')
while True:
    print("Finished 1 Cycle")
    while time.time() - start_time < 2200:
        time.sleep(30)
    action = sb._train_advanced_squire
    sb.execute_action_on_squires(0, 11, action, missions_by_id=missions_by_id)
    start_time = time.time()

# %%
# Alt
missions_by_id = {0: [0, -1, 6], 1: [0, -1, 6], 2: [0, -1, 6], 3: [0, 3, -1],
                      4: [0, -1, 6], 5: [0, -1, 6], 6: [0, -1, 6], 7: [0, -1, 6],
                      8: [0, -1, 6], 9: [0, -1, 6], 10: [0, -1, 6], 11: [0, -1, 6]}
action = sb._train_advanced_squire
sb.execute_action_on_squires(10, 11, action, missions_by_id=missions_by_id, mission_number=3)
# Out:
# ./confirms/login_confirm.png 0.05325106903910637 0.06 True
# ./confirms/new_day_confirm.png 0.22795948386192322 0.12 False
# ./confirms/avalon_confirm.png 0.03263379633426666 0.07 True
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-19971355dc53> in <module>
#       4                       8: [0, -1, 6], 9: [0, -1, 6], 10: [0, -1, 6], 11: [0, -1, 6]}
#       5 action = sb._train_advanced_squire
# ----> 6 sb.execute_action_on_squires(10, 11, action, missions_by_id=missions_by_id, mission_number=3)
#
# ~\Documents\GitHub\ProjectPhoenix\squirebot.py in execute_action_on_squires(self, start, num_chars, action, **kwargs)
#      32             kwargs['squire_id'] = i
#      33             self._login(i)
# ---> 34             action(**kwargs)
#      35             self._logout()
#      36
#
# ~\Documents\GitHub\ProjectPhoenix\squirebot.py in _train_advanced_squire(self, missions_by_id, squire_id, mission_number, **kwargs)
#      51         self._mabi_zoom(12, -500)
#      52         self._move_to_squire("kanna")
# ---> 53         self._end_training()
#      54         self._converse_with_squire()
#      55         self._start_training(3)
#
# ~\Documents\GitHub\ProjectPhoenix\squirebot.py in _end_training(self)
#     105
#     106     def _end_training(self):
# --> 107         self._talk_to_squire()
#     108         self._mabi_click(980, 670, delay=0.5, apply_sfactor=self.apply_factor)
#     109         self._mabi_click(660, 1880, delay=0.5, apply_cfactor=self.apply_factor)
#
# ~\Documents\GitHub\ProjectPhoenix\squirebot.py in _talk_to_squire(self)
#      80         ReleaseKey(CTRL)
#      81
# ---> 82         screen_text = self._get_screen_tesseract_text(950, 450, 1000, 900)
#      83         while 'Conversation' not in screen_text and 'Counsel' not in screen_text:
#      84             self._mabi_click(980, 530, delay=0.5, apply_sfactor=self.apply_factor)
#
# ~\Documents\GitHub\ProjectPhoenix\squirebot.py in _get_screen_tesseract_text(self, x1, y1, x2, y2, apply_factor)
#     137         x_factor = self.x_sfactor if apply_factor else 0
#     138
# --> 139         text_cutout = screen[x1+xfactor:x2+xfactor, y1+yfactor:y2+yfactor]
#     140         text_cutout = cv2.resize(text_cutout,None,fx=4,fy=4)
#     141         ret, text_cutout = cv2.threshold(text_cutout,127,255,cv2.THRESH_BINARY)
#
# NameError: name 'xfactor' is not defined

# %% [markdown]
# # Macros

# %%
# Buy boxes
int_seals = 362
sb.box_buying(int_seals)

# %%
num_leathers = 85
sb.make_leather_straps(num_leathers)

# %%
num_syn = 40
sb.synthesize(num_syn)

# %% [markdown]
# # Test Functions

# %%
sb.alt_tab()
# sb._end_training()
sb._start_training(0)

# %%
import time
missions_by_id = {0: [3, 0, -1], 1: [0, -1, 6], 2: [0, -1, 6], 3: [0, -1, 6],
                      4: [0, -1, 6], 5: [0, -1, 6], 6: [0, -1, 6], 7: [0, -1, 6],
                      8: [0, -1, 6], 9: [0, -1, 6], 10: [0, -1, 6], 11: [0, -1, 6]}

sb.alt_tab()
# sb._reassign_missions(missions_by_id, 0)
# sb._reset_char_screen()
# sb._converse_with_squire()
# sb._start_training(3)
time.sleep(2200)
while True:
    sb._reassign_missions(missions_by_id, 0)
    sb._reset_char_screen()
    sb._end_training()
    sb._converse_with_squire()
    sb._start_training(3)
    time.sleep(2200)

# %%
sb.alt_tab()
for i in range(3):
    sb._click_through_text()
    sb._answer_conv_question()
    sb._end_conv()

# %%
sb.alt_tab()
missions_by_id = {0: [0, 3, -1], 1: [0, -1, 6], 2: [0, -1, 6], 3: [0, -1, 6],
                      4: [0, -1, 6], 5: [0, -1, 6], 6: [0, -1, 6], 7: [0, -1, 6],
                      8: [0, -1, 6], 9: [0, -1, 6], 10: [0, -1, 6], 11: [0, -1, 6]}
sb._reassign_missions(missions_by_id, 0, number=2)

# %%
import pyautogui
from directkeys import PressKey, ReleaseKey, W, A, S, D, SHIFT, CTRL, ESC, C
import time
sb.alt_tab()

#sb._end_training()
#sb._converse_with_squire()
sb._start_training(0)
# Out:
# 1010 1060 450 900
# Start a Conversation
#
# Counsel
#
# Go Out
#
# Tart a LaLa)
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# <ipython-input-20-13c50d053438> in <module>
#       4 sb.alt_tab()
#       5
# ----> 6 sb._end_training()
#       7 #sb._converse_with_squire()
#       8 sb._start_training(0)
#
# ~\Documents\GitHub\ProjectPhoenix\squirebot.py in _end_training(self)
#     108         self._mabi_click(980, 670, delay=0.5, apply_sfactor=self.apply_factor)
#     109         self._mabi_click(660, 1880, delay=0.5)
# --> 110         self._mabi_click(610, 1000, delay=1)
#     111         self._mabi_click(980, 530, delay=0.5, apply_sfactor=self.apply_factor)
#     112         PressKey(W)
#
# ~\Documents\GitHub\ProjectPhoenix\squirebot.py in _mabi_click(self, h, w, delay, clickDelay, multi_click, apply_sfactor, apply_cfactor)
#     272         for i in range(multi_click):
#     273             pyautogui.moveTo(w+y_sfactor+y_cfactor, h+x_sfactor+x_cfactor)
# --> 274             pyautogui.mouseDown();
#     275             time.sleep(clickDelay);
#     276             pyautogui.mouseUp()
#
# C:\ProgramData\Anaconda3\envs\squire\lib\site-packages\pyautogui\__init__.py in mouseDown(x, y, button, duration, tween, pause, logScreenshot, _pause)
#     421     """
#     422     button = _translateButton(button)
# --> 423     _failSafeCheck()
#     424     x, y = _unpackXY(x, y)
#     425
#
# C:\ProgramData\Anaconda3\envs\squire\lib\site-packages\pyautogui\__init__.py in _failSafeCheck()
#    1239 def _failSafeCheck():
#    1240     if FAILSAFE and tuple(position()) in FAILSAFE_POINTS:
# -> 1241         raise FailSafeException('PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.')
#    1242
#    1243
#
# FailSafeException: PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.
